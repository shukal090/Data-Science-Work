# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

# %%
train=pd.read_csv('data.csv')

# %%
train.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# ...

# %%
train.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
train.isnull().sum()
# Out:
# Unnamed: 0                      0
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Real Face                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# ...

# %%
train.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
train=train.iloc[:,0:18]
train
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
train.isnull().sum()
# Out:
# Unnamed: 0                    0
# ID                            0
# Name                          0
# Age                           0
# Photo                         0
# Nationality                   0
# Flag                          0
# Overall                       0
# Potential                     0
# Club                        241
# Club Logo                     0
# Value                         0
# Wage                          0
# Special                       0
# Preferred Foot               48
# International Reputation     48
# Weak Foot                    48
# Skill Moves                  48
# dtype: int64

# %%
train["Club"].fillna("NA", inplace = True)
train["Preferred Foot"].fillna("Both", inplace=True)

train["Weak Foot"].fillna("NA", inplace=True)

train["Skill Moves"].fillna(1, inplace=True)

train["International Reputation"].fillna(1, inplace=True)

# %%
train.isnull().sum()
# Out:
# Unnamed: 0                  0
# ID                          0
# Name                        0
# Age                         0
# Photo                       0
# Nationality                 0
# Flag                        0
# Overall                     0
# Potential                   0
# Club                        0
# Club Logo                   0
# Value                       0
# Wage                        0
# Special                     0
# Preferred Foot              0
# International Reputation    0
# Weak Foot                   0
# Skill Moves                 0
# dtype: int64

# %%
train.corr()
# Out:
#                           Unnamed: 0        ID       Age   Overall  Potential  \
# Unnamed: 0                  1.000000  0.415757 -0.454846 -0.972791  -0.633395
# ID                          0.415757  1.000000 -0.739208 -0.417025   0.047074
# Age                        -0.454846 -0.739208  1.000000  0.452350  -0.253312
# Overall                    -0.972791 -0.417025  0.452350  1.000000   0.660939
# Potential                  -0.633395  0.047074 -0.253312  0.660939   1.000000
# Special                    -0.596508 -0.231352  0.236695  0.606960   0.383727
# International Reputation   -0.413535 -0.355900  0.253457  0.499654   0.372887
# Skill Moves                -0.417308 -0.057724  0.027623  0.415402   0.355652
#
#                            Special  International Reputation  Skill Moves
# Unnamed: 0               -0.596508                 -0.413535    -0.417308
# ID                       -0.231352                 -0.355900    -0.057724
# ...

# %%
sns.heatmap(data.corr())

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-6cc0674ecdbf> in <module>
#       1 train.plot(kind="scatter",x="Age",y="Overall",color="Red",alpha=0.8)
# ----> 2 plt.set_xlabel("Age")
#       3 plt.set_ylabel('Overall')
#       4 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'set_xlabel'

# %%
sns.pairplot(train,hue='Age',palette='rainbow')
# Out:
# E:\Anaconda\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# E:\Anaconda\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# E:\Anaconda\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# E:\Anaconda\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
train[train["Club"]=="FC Barcelona"].Vision .plot(kind="line" , color ="blue" , label = "Vision " , alpha=0.5 , grid=True)
train[train["Club"]=="FC Barcelona"].Marking.plot(kind="line" , color ="green" , label = "Marking" , alpha=0.5, grid=True)
plt.xlabel("x")     
plt.ylabel("y")
plt.title("line graph")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-87b3b7456688> in <module>
# ----> 1 train[train["Club"]=="FC Barcelona"].Vision .plot(kind="line" , color ="blue" , label = "Vision " , alpha=0.5 , grid=True)
#       2 train[train["Club"]=="FC Barcelona"].Marking.plot(kind="line" , color ="green" , label = "Marking" , alpha=0.5, grid=True)
#       3 plt.xlabel("x")
#       4 plt.ylabel("y")
#       5 plt.title("line graph")
#
# E:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Vision'

# %%
sns.set(style ="dark",color_codes=True)
x = train.Age
plt.figure
ax = sns.distplot(x, bins = 30, kde = False, color='b')
ax.set_xlabel(xlabel="Age", fontsize=16)
ax.set_ylabel(ylabel='Count of players', fontsize=16)
ax.set_title(label='Distribution of players age', fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-7358c50746ed> in <module>
#       6 ax.set_ylabel(ylabel='Count of players', fontsize=16)
#       7 ax.set_title(label='Distribution of players age', fontsize=20)
# ----> 8 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
train.hist('Age', figsize=(7,7))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B95C3763C8>]],
#       dtype=object)

# %%
train[['Name','Age','Value','Wage']].max()
# Out:
# Name     Óscar Whalley
# Age                 45
# Value              €9M
# Wage               €9K
# dtype: object

# %%
train[['Name','Age','Value','Wage']].min()
# Out:
# Name     A. Abang
# Age            16
# Value          €0
# Wage           €0
# dtype: object

# %%
train[['Overall','Age','Potential']].mean()
# Out:
# Overall      66.238699
# Age          25.122206
# Potential    71.307299
# dtype: float64

# %%
train[train["Club"]=="Chelsea"][['Name','Overall','Age','Wage','Nationality']].head(10)
# Out:
#               Name  Overall  Age   Wage Nationality
# 5        E. Hazard       91   27  €340K     Belgium
# 14        N. Kanté       89   27  €225K      France
# 69     Azpilicueta       86   28  €175K       Spain
# 121       Jorginho       84   26  €155K       Italy
# 140        Willian       84   29  €175K      Brazil
# 176     M. Kovačić       83   24  €165K     Croatia
# 177           Kepa       83   23   €84K       Spain
# 200  Marcos Alonso       83   27  €130K       Spain
# 209     David Luiz       83   31  €130K      Brazil
# 219  Cesc Fàbregas       83   31  €140K       Spain

# %%
 train.sort_values('Age', ascending = True)[['Name', 'Nationality','Club', 'Age']].head(10)
# Out:
#                  Name          Nationality             Club  Age
# 18206       G. Nugent              England  Tranmere Rovers   16
# 17743       J. Olstad               Norway  Sarpsborg 08 FF   16
# 13293     H. Massengo               France        AS Monaco   16
# 16081     J. Italiano            Australia      Perth Glory   16
# 18166        N. Ayéva               Sweden        Örebro SK   16
# 17712        K. Broda               Poland     Wisła Kraków   16
# 17354     L. D'Arrigo            Australia  Adelaide United   16
# 13567  Y. Verschaeren              Belgium   RSC Anderlecht   16
# 16927       B. Nygren               Sweden     IFK Göteborg   16
# 18018     B. O'Gorman  Republic of Ireland   Bray Wanderers   16

# %%
train.groupby(['Nationality'])['Age'].sum().sort_values(ascending = False).head(5)
# Out:
# Nationality
# England      39938
# Germany      29157
# Spain        27149
# Argentina    24555
# Brazil       22846
# Name: Age, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-c31e5c79ed12> in <module>
#       1 x=train['Skill Moves']
#       2 y=train['Special']
# ----> 3 plt.hexbin(x, y, gridsize=(30,30))
#       4 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'hexbin'
